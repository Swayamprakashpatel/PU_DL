# %% [markdown]
# <a href="https://colab.research.google.com/github/Swayamprakashpatel/PU_DL/blob/main/PU_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
#Set Batch Size and Image Height and Image Width
batch_size = 10
IMG_HEIGHT, IMG_WIDTH = (50,50)

# Show image after Size Setting (Reduction)
plt.figure(figsize=(IMG_HEIGHT,IMG_WIDTH))
img_folder=r'/content/drive/MyDrive/Model_DE/Model Try/MIXED'
for i in range(2):
    file = random.choice(os.listdir(img_folder))
    image_path= os.path.join(img_folder, file)
    img=mpimg.imread(image_path,cv2.COLOR_RGB2BGR)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
#Directories with Subdirectories as Classes for training and validation datasets

train_dir = '/content/drive/MyDrive/Model_DE/Model Try'
validation_dir = '/content/drive/MyDrive/Model_DE/Model Try'

# %%
#Image to Data Transform using ImageDataGenerator of Keras

#Image to Data for Training Data
Dataset_Image_Training = ImageDataGenerator(rescale = 1./255)
train_data_gen =  Dataset_Image_Training.flow_from_directory(
                    batch_size= batch_size,
                    directory=train_dir,
                    shuffle=True,
                    target_size=(IMG_HEIGHT,IMG_WIDTH),
                    class_mode='binary',
                    )
#Image to Data for Validation Data
validation_image_generator = ImageDataGenerator(rescale=1./255)
val_data_gen = validation_image_generator.flow_from_directory(
                 batch_size=batch_size,
                 directory= validation_dir,
                 shuffle=True,
                 target_size=(IMG_HEIGHT,IMG_WIDTH),
                 class_mode= 'binary')
#Check Classes in Dataset
train_data_gen.class_indices
# Out:
# Found 154 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# {'MIXED': 0, 'NOT MIXED': 1}

# %%
#Deep Learning CNN Model with Keras Seqential

model = Sequential([
    Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)),
    MaxPool2D(2,2),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPool2D(2,2),
    Conv2D(128, (3,3), padding='same', activation='relu'),
    MaxPool2D(2,2),
    Conv2D(256, (3,3), padding='same', activation='relu'),
    MaxPool2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')])

# Model Compilation
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

#Checkpoint and earlystop setting
filepath = '/content/drive/My Drive/DL_Model.hdf5'
checkpoint = [tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', mode='max', save_best_only=True, Save_weights_only = False, verbose = 1), 
              tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=25, verbose =1)]

#Model Fitting
history = model.fit(
    train_data_gen,
    steps_per_epoch=None,
    epochs=500,
    validation_data=val_data_gen,
    validation_steps=None,
    callbacks = [checkpoint],
)
# Out:
# Epoch 1/500
# 16/16 [==============================] - 36s 2s/step - loss: 0.7405 - accuracy: 0.4545 - val_loss: 0.6929 - val_accuracy: 0.5065
#
# Epoch 00001: val_accuracy improved from -inf to 0.50649, saving model to /content/drive/My Drive/DL_Model.hdf5
# Epoch 2/500
# 16/16 [==============================] - 3s 195ms/step - loss: 0.6940 - accuracy: 0.4805 - val_loss: 0.6930 - val_accuracy: 0.4935
#
# Epoch 00002: val_accuracy did not improve from 0.50649
# Epoch 3/500
# 16/16 [==============================] - 3s 196ms/step - loss: 0.6933 - accuracy: 0.4675 - val_loss: 0.6927 - val_accuracy: 0.5065
#
# Epoch 00003: val_accuracy did not improve from 0.50649
# Epoch 4/500
# 16/16 [==============================] - 3s 201ms/step - loss: 0.6941 - accuracy: 0.4675 - val_loss: 0.6926 - val_accuracy: 0.4935
#
# Epoch 00004: val_accuracy did not improve from 0.50649
# Epoch 5/500
# 16/16 [==============================] - 3s 195ms/step - loss: 0.6931 - accuracy: 0.5130 - val_loss: 0.6925 - val_accuracy: 0.9091
#
# Epoch 00005: val_accuracy improved from 0.50649 to 0.90909, saving model to /content/drive/My Drive/DL_Model.hdf5
# Epoch 6/500
# 16/16 [==============================] - 3s 195ms/step - loss: 0.6927 - accuracy: 0.5649 - val_loss: 0.6911 - val_accuracy: 0.6494
#
# Epoch 00006: val_accuracy did not improve from 0.90909
# Epoch 7/500
# 16/16 [==============================] - 3s 194ms/step - loss: 0.6912 - accuracy: 0.5130 - val_loss: 0.6881 - val_accuracy: 0.8442
#
# Epoch 00007: val_accuracy did not improve from 0.90909
# Epoch 8/500
# 16/16 [==============================] - 3s 201ms/step - loss: 0.6856 - accuracy: 0.7922 - val_loss: 0.6750 - val_accuracy: 0.8052
#
# Epoch 00008: val_accuracy did not improve from 0.90909
# Epoch 9/500
# 16/16 [==============================] - 3s 199ms/step - loss: 0.6788 - accuracy: 0.5779 - val_loss: 0.6516 - val_accuracy: 0.9610
#
# Epoch 00009: val_accuracy improved from 0.90909 to 0.96104, saving model to /content/drive/My Drive/DL_Model.hdf5
# Epoch 10/500
# 16/16 [==============================] - 3s 196ms/step - loss: 0.6374 - accuracy: 0.7208 - val_loss: 0.5647 - val_accuracy: 0.8831
#
# Epoch 00010: val_accuracy did not improve from 0.96104
# Epoch 11/500
# 16/16 [==============================] - 3s 202ms/step - loss: 0.5496 - accuracy: 0.7857 - val_loss: 0.4731 - val_accuracy: 0.7013
#
# Epoch 00011: val_accuracy did not improve from 0.96104
# Epoch 12/500
# 16/16 [==============================] - 3s 195ms/step - loss: 0.4675 - accuracy: 0.7792 - val_loss: 0.2948 - val_accuracy: 0.9091
#
# Epoch 00012: val_accuracy did not improve from 0.96104
# Epoch 13/500
# 16/16 [==============================] - 3s 200ms/step - loss: 0.2274 - accuracy: 0.9221 - val_loss: 0.0907 - val_accuracy: 1.0000
#
# Epoch 00013: val_accuracy improved from 0.96104 to 1.00000, saving model to /content/drive/My Drive/DL_Model.hdf5
# Epoch 14/500
# 16/16 [==============================] - 3s 194ms/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
#
# Epoch 00014: val_accuracy did not improve from 1.00000
# Epoch 15/500
# 16/16 [==============================] - 3s 200ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
#
# Epoch 00015: val_accuracy did not improve from 1.00000
# Epoch 16/500
# 16/16 [==============================] - 3s 194ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
#
# Epoch 00016: val_accuracy did not improve from 1.00000
# Epoch 17/500
# 16/16 [==============================] - 3s 198ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
#
# Epoch 00017: val_accuracy did not improve from 1.00000
# Epoch 18/500
# 16/16 [==============================] - 3s 198ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 7.1907e-04 - val_accuracy: 1.0000
#
# Epoch 00018: val_accuracy did not improve from 1.00000
# Epoch 19/500
# 16/16 [==============================] - 3s 200ms/step - loss: 6.5655e-04 - accuracy: 1.0000 - val_loss: 5.8459e-04 - val_accuracy: 1.0000
#
# Epoch 00019: val_accuracy did not improve from 1.00000
# Epoch 20/500
# 16/16 [==============================] - 3s 203ms/step - loss: 5.4374e-04 - accuracy: 1.0000 - val_loss: 4.8907e-04 - val_accuracy: 1.0000
#
# Epoch 00020: val_accuracy did not improve from 1.00000
# Epoch 21/500
# 16/16 [==============================] - 3s 198ms/step - loss: 4.6701e-04 - accuracy: 1.0000 - val_loss: 4.2779e-04 - val_accuracy: 1.0000
#
# Epoch 00021: val_accuracy did not improve from 1.00000
# Epoch 22/500
# 16/16 [==============================] - 3s 199ms/step - loss: 4.0685e-04 - accuracy: 1.0000 - val_loss: 3.8055e-04 - val_accuracy: 1.0000
#
# Epoch 00022: val_accuracy did not improve from 1.00000
# Epoch 23/500
# 16/16 [==============================] - 3s 200ms/step - loss: 3.6844e-04 - accuracy: 1.0000 - val_loss: 3.3715e-04 - val_accuracy: 1.0000
#
# Epoch 00023: val_accuracy did not improve from 1.00000
# Epoch 24/500
# 16/16 [==============================] - 3s 194ms/step - loss: 3.2280e-04 - accuracy: 1.0000 - val_loss: 3.0567e-04 - val_accuracy: 1.0000
#
# Epoch 00024: val_accuracy did not improve from 1.00000
# Epoch 25/500
# 16/16 [==============================] - 3s 199ms/step - loss: 2.9513e-04 - accuracy: 1.0000 - val_loss: 2.7803e-04 - val_accuracy: 1.0000
#
# Epoch 00025: val_accuracy did not improve from 1.00000
# Epoch 26/500
# 16/16 [==============================] - 3s 192ms/step - loss: 2.7016e-04 - accuracy: 1.0000 - val_loss: 2.5497e-04 - val_accuracy: 1.0000
#
# Epoch 00026: val_accuracy did not improve from 1.00000
# Epoch 27/500
# 16/16 [==============================] - 3s 196ms/step - loss: 2.4734e-04 - accuracy: 1.0000 - val_loss: 2.3435e-04 - val_accuracy: 1.0000
#
# Epoch 00027: val_accuracy did not improve from 1.00000
# Epoch 28/500
# 16/16 [==============================] - 3s 197ms/step - loss: 2.2756e-04 - accuracy: 1.0000 - val_loss: 2.1644e-04 - val_accuracy: 1.0000
#
# Epoch 00028: val_accuracy did not improve from 1.00000
# Epoch 29/500
# 16/16 [==============================] - 3s 198ms/step - loss: 2.1001e-04 - accuracy: 1.0000 - val_loss: 2.0101e-04 - val_accuracy: 1.0000
#
# Epoch 00029: val_accuracy did not improve from 1.00000
# Epoch 30/500
# 16/16 [==============================] - 3s 195ms/step - loss: 1.9566e-04 - accuracy: 1.0000 - val_loss: 1.8700e-04 - val_accuracy: 1.0000
#
# Epoch 00030: val_accuracy did not improve from 1.00000
# Epoch 31/500
# 16/16 [==============================] - 3s 201ms/step - loss: 1.8263e-04 - accuracy: 1.0000 - val_loss: 1.7461e-04 - val_accuracy: 1.0000
#
# Epoch 00031: val_accuracy did not improve from 1.00000
# Epoch 32/500
# 16/16 [==============================] - 3s 197ms/step - loss: 1.7029e-04 - accuracy: 1.0000 - val_loss: 1.6313e-04 - val_accuracy: 1.0000
#
# Epoch 00032: val_accuracy did not improve from 1.00000
# Epoch 33/500
# 16/16 [==============================] - 3s 203ms/step - loss: 1.5933e-04 - accuracy: 1.0000 - val_loss: 1.5360e-04 - val_accuracy: 1.0000
#
# Epoch 00033: val_accuracy did not improve from 1.00000
# Epoch 34/500
# 16/16 [==============================] - 3s 196ms/step - loss: 1.5002e-04 - accuracy: 1.0000 - val_loss: 1.4452e-04 - val_accuracy: 1.0000
#
# Epoch 00034: val_accuracy did not improve from 1.00000
# Epoch 35/500
# 16/16 [==============================] - 3s 194ms/step - loss: 1.4123e-04 - accuracy: 1.0000 - val_loss: 1.3620e-04 - val_accuracy: 1.0000
#
# Epoch 00035: val_accuracy did not improve from 1.00000
# Epoch 36/500
# 16/16 [==============================] - 3s 200ms/step - loss: 1.3370e-04 - accuracy: 1.0000 - val_loss: 1.2907e-04 - val_accuracy: 1.0000
#
# Epoch 00036: val_accuracy did not improve from 1.00000
# Epoch 37/500
# 16/16 [==============================] - 3s 194ms/step - loss: 1.2590e-04 - accuracy: 1.0000 - val_loss: 1.2180e-04 - val_accuracy: 1.0000
#
# Epoch 00037: val_accuracy did not improve from 1.00000
# Epoch 38/500
# 16/16 [==============================] - 3s 194ms/step - loss: 1.1975e-04 - accuracy: 1.0000 - val_loss: 1.1516e-04 - val_accuracy: 1.0000
#
# Epoch 00038: val_accuracy did not improve from 1.00000
# Epoch 00038: early stopping

# %%
#Predictionn

Pred_Dir = '/content/drive/MyDrive/Model_DE/Test'
Prediction = ImageDataGenerator(rescale = 1./255)
Pred_Data =  Prediction.flow_from_directory(
                    directory=Pred_Dir,
                    batch_size= batch_size,
                    shuffle=False,
                    target_size=(IMG_HEIGHT,IMG_WIDTH),
                    class_mode=None)
#Pred_Data.reset()

Prediction = np.round(model.predict(Pred_Data))
k = print(Prediction)
train_data_gen.class_indices
# Out:
# Found 1 images belonging to 1 classes.
# [[1.]]
# {'MIXED': 0, 'NOT MIXED': 1}
